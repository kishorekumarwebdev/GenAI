# %% [markdown]
# <a href="https://colab.research.google.com/github/kishorekumarwebdev/GenAI/blob/GENAI/Content%20Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers torch accelerate

from transformers import pipeline

generator = pipeline('text-generation', model='gpt2')
prompt = input("Enter ur prompt")

generated_tet=generator(prompt,max_length=300,do_sample=True,top_k=10,temperature=0.8)
print(generated_tet[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter ur promptaritificial intelligence
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length', 'temperature', 'top_k', 'do_sample'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=300) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# aritificial intelligence. The company is developing a computer model to help doctors diagnose the condition.
#
# The research comes after a year of research by researchers at the University of Texas at Austin that showed artificial intelligence could provide the best diagnosis for people who suffer from the disease.
#
# ...
